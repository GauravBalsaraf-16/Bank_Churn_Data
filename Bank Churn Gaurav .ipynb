# %% [markdown]
# # Exploring Bank Churn Data

# %% [markdown]
# # 3 Levels for Data Exploration
#
# * Level 0 : Understanding Data
# * Level 1 : Univariate Analysis
# * Level 2 : Bi-Variate Analysis
# * Lever 3 : Multivariate Analysis and asking questions from data

# %% [markdown]
# ## Level 0 Tasks : Understanding Data
#
# 1.Visually inspect the first few and last few rows of the data \
# 2.Check the shape of the data frame \
# 3.Check the count of null values in each column \
# 4.Inspect all the column names and cross check with the data dictionary \
# 5.Check the information of the data frame using the info() function

# %% [markdown]
# ## Importing the necessary libraries

# %%
import numpy as np                  ## for numerical computation 
import pandas as pd                 ## for data reading 
import matplotlib.pyplot as plt     ## to data visulalization
import seaborn as sns               ## to data visulalization
import matplotlib as mat            ## to data visulalization
from tabulate import tabulate       ## to print the table

# %%
## To check the versions of toolkits 
print("Pandas Version" ,pd.__version__)
print("Seaborn Version" ,sns.__version__)
print("Matplotlib Version", mat.__version__)
# Out:
# Pandas Version 1.4.4
# Seaborn Version 0.11.2
# Matplotlib Version 3.5.2

# %% [markdown]
# ## Reading the File

# %%
Bank = pd.read_csv("DS1_C6_S1_BankChurn_Data_Concept.csv")

# %%
Bank     ## to show the file
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
Bank.head()                 ## to check the first five rows
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0              39                         5                       1
# ...

# %%
Bank.tail()               ## to check the last five rows
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# ...

# %%
Bank.columns                  ## to check the column names in data frame
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Trans_Amt', 'Total_Trans_Ct',
#        'Avg_Utilization_Ratio'],
#       dtype='object')

# %%
Bank.shape                 ## to check the rows and column count
# Out:
# (10127, 19)

# %%
Bank.info()                   ## to check the whole dataframe information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10034 non-null  object
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             9995 non-null   object
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
# ...

# %%
Bank.isnull().sum()                     ## to check the null values
# Out:
# CLIENTNUM                     0
# Attrition_Flag                0
# Customer_Age                  0
# Gender                       93
# Dependent_count               0
# Education_Level               0
# Marital_Status                0
# Income_Category               0
# Card_Category               132
# Months_on_book                0
# Total_Relationship_Count      0
# Months_Inactive_12_mon        0
# Contacts_Count_12_mon         0
# Credit_Limit                 60
# Total_Revolving_Bal           0
# Avg_Open_To_Buy               0
# Total_Trans_Amt               0
# Total_Trans_Ct                0
# Avg_Utilization_Ratio         0
# dtype: int64

# %% [markdown]
# LEVEL 1 Analysis
# -------------------------
# Identify if the type data in each column is categorical or numerical?
# 1. Separate out the categorical columns from the numerical types
#
# ### These are the kind of analyses that can be performed on categorical data
# 1. Check if it is Nominal or Ordinal
# 2. Check how many categories are present
# 3. Check the Mode
# 4. Check for Missing values
# 5. Think about how the missing values could be treated
# 6. Think about the kind of graph/chart that can be plotted using this data
#
# Note: We are analyzing only one column at a time (Univariate Analysis).

# %% [markdown]
# ## Separating the categoriacal and numerical values

# %%
def separate_values(dataset):
    categorical= []
    continuous = []
    for column in dataset.columns:
        if dataset[column].nunique() <50:
            categorical.append(column)
        else :
            continuous.append(column)
    return categorical, continuous 

categorical, continuous = separate_values(Bank)

# %%
from tabulate import tabulate 
table = [categorical, continuous]
print(tabulate ({"categorical": categorical, "continuous" : continuous}, headers = ["categorical", "continuous"]))
# Out:
# categorical               continuous
# ------------------------  ---------------------
# Attrition_Flag            CLIENTNUM
# Gender                    Customer_Age
# Education_Level           Dependent_count
# Marital_Status            Credit_Limit
# Income_Category           Total_Revolving_Bal
# Card_Category             Avg_Open_To_Buy
# Months_on_book            Total_Trans_Amt
# Total_Relationship_Count  Total_Trans_Ct
# Months_Inactive_12_mon    Avg_Utilization_Ratio
# Contacts_Count_12_mon

# %% [markdown]
# # $$\;\;\;\; Univariate \ Analysis \ of \ Categorical \ Variables$$

# %% [markdown]
#  ## Level 1 analysis (Univariate analysis)

# %% [markdown]
# ### User defined function for level 1 analysis of categorical columns
# This function will check for the following \
# Unique values \
# Mode \
# Total count of missing values

# %%
def info_of_cat(col):
    print(f"The Unique values in {col} are: {Bank[col].unique()}")
    print(f"The mode in {col} are : {Bank[col].mode()[0]}")
    print(f"number of missing values {col} are: {Bank[col].isnull().sum()}")

# %%
info_of_cat("Attrition_Flag")
# Out:
# The Unique values in Attrition_Flag are: ['Existing Customer' 'Attrited Customer']
# The mode in Attrition_Flag are : Existing Customer
# number of missing values Attrition_Flag are: 0

# %% [markdown]
# Attrition Flag is Nominal datatype.

# %% [markdown]
# Visual representation of Attrition Flag

# %%
fig, ax = plt.subplots(1,2, figsize = (10,5))
ax[0].set_title("Count of Attrition flag")
ax[1].set_title("Pie chart of Attrition Flag")

percentage = Bank["Attrition_Flag"].value_counts()
labels = list(percentage.index)

sns.countplot(x= Bank["Attrition_Flag"], ax= ax[0])
plt.pie(percentage, labels = labels, autopct = "%1.1f%%", colors = ["Blue", "Orange"])
plt.show()

# %% [markdown]
# ## ***Interpretation:  The dataset indicates that 16% of the customers left the bank while 84% of the customers are still with it

# %% [markdown]
# ## 2. Analysis of Gender column : Gender of a person (Male or Female)

# %%
info_of_cat("Gender")
# Out:
# The Unique values in Gender are: ['M' 'F' nan]
# The mode in Gender are : F
# number of missing values Gender are: 93

# %% [markdown]
# Gender is a Nominal type. (categorical)

# %%
Gender_mode = Bank.Gender.mode()[0]
print(Gender_mode)
Bank["Gender"].fillna(Gender_mode, inplace= True)
# Out:
# F

# %% [markdown]
# Basic visualization of gender column

# %%
fig, ax = plt.subplots(1,2, figsize=(10,7))
value_gender = Bank["Gender"].value_counts()
labels = value_gender.keys()

sns.countplot(x = Bank["Gender"], ax = ax[0])
plt.pie(x = value_gender, autopct = "%1.1f%%", explode=[0.02, 0], labels = labels)

plt.show()

# %% [markdown]
# ## Interpretation : Female customers are more in numbers contributing 53%

# %% [markdown]
# ## Analysis number of dependent counts : Number of dependents on each counts

# %%
info_of_cat("Dependent_count")
# Out:
# The Unique values in Dependent_count are: [  3   5   4   2   0   1   9  29 103  22  25  78  90  35  60  42 119 104
#   88  48  34 143 100  59 130  95   7  82  69  92 110  17  10  27  19 109
#  142 116 113 125  80  63  24  97 102  52  87  11 117  13  67  89  61  72
#  120  76]
# The mode in Dependent_count are : 3
# number of missing values Dependent_count are: 0

# %% [markdown]
# Dependent count is an ordinal type data. (Categorical)

# %% [markdown]
# Visualization of Dependent_count

# %%
fig, ax = plt.subplots(figsize= (10, 7))
ax = sns.countplot(x = Bank["Dependent_count"])
for bar in ax.patches:                                              # ax.patches returns the rectange object from matplotlib
    percentage = f"{round(bar.get_height() /len(Bank), 2)}%"          # first it calculate the bar height and then dividing by the number of rows in data(to calculate percentage) 
                                                                    # and multiply with 100 to get the percentage and rounding of by 2 numbers.  
    x = bar.get_x() + bar.get_width() /2                            # get_x: returns the left corrdinate of the rectange, get_width: returns width of rectagle
    y = bar.get_height()                                            # get_height: returns height of rectange
    ax.annotate(percentage, (x, y), va = "bottom", ha ="center" )   # va bottom: means percentage would be above the bar head. 
    fig.set_figheight(10)                                                             # annotate: used to annotate over objects, here objects are the bars
    fig.set_figwidth(30)
plt.show()

# %%
fig,ax = plt.subplots(figsize = (10,7))
ax= sns.countplot(x = Bank["Dependent_count"])
for bar in ax.patches:
    percentage= f"{round(bar.get_height() / len(Bank),2)}%"
    
    x = bar.get_x() + bar.get_height() / 2
    y = bar.get_height()
    
    ax.annotate(percentage,(x,y), va = 'bottom', ha = "center")
    fig.set_figheight(10)
    fig.set_figwidth(30)
    
plt.show()

# %% [markdown]
# ## ***Interpretation: Very few people are having more than 5 dependents. However, there are some cases where the dependent count is greater than 100, which is abnormal. Hence, data clearing might be  required.

# %% [markdown]
# ## Outliers analysis and treatment

# %% [markdown]
# The customers who has dependent count more than 5, will be replaced by mean of the population.

# %%
info_of_cat("Dependent_count")
# Out:
# The Unique values in Dependent_count are: [  3   5   4   2   0   1   9  29 103  22  25  78  90  35  60  42 119 104
#   88  48  34 143 100  59 130  95   7  82  69  92 110  17  10  27  19 109
#  142 116 113 125  80  63  24  97 102  52  87  11 117  13  67  89  61  72
#  120  76]
# The mode in Dependent_count are : 3
# number of missing values Dependent_count are: 0

# %%
## making changes in data set 

mean = int(Bank.Dependent_count.mean())

x = Bank[Bank["Dependent_count"] > 5].index

for index in x:
    Bank.loc[index, "Dependent_count"] = mean

# %%
info_of_cat("Dependent_count")
# Out:
# The Unique values in Dependent_count are: [3 5 4 2 0 1]
# The mode in Dependent_count are : 3
# number of missing values Dependent_count are: 0

# %%
fig, ax = plt.subplots(figsize= (10, 7))
ax = sns.countplot(x = Bank["Dependent_count"])
for bar in ax.patches:                                              # ax.patches returns the rectange object from matplotlib
    percentage = f"{round(bar.get_height() /len(Bank), 2)}%"          # first it calculate the bar height and then dividing by the number of rows in data(to calculate percentage) 
                                                                    # and multiply with 100 to get the percentage and rounding of by 2 numbers.  
    x = bar.get_x() + bar.get_width() /2                            # get_x: returns the left corrdinate of the rectange, get_width: returns width of rectagle
    y = bar.get_height()                                            # get_height: returns height of rectange
    ax.annotate(percentage, (x, y), va = "bottom", ha ="center" )   # va bottom: means percentage would be above the bar head. 
                                                                    # annotate: used to annotate over objects, here objects are the bars
plt.show()

# %% [markdown]
# ## ***Interpretation: Card holders usually have 2 to 3 dependents on them which adds up to 53% of the total population.

# %% [markdown]
# ## Analysis of education level: education level of card owner

# %%
info_of_cat("Education_Level")
# Out:
# The Unique values in Education_Level are: ['High School' 'Graduate' 'Uneducated' 'Unknown' 'College' 'Post-Graduate'
#  'Doctorate']
# The mode in Education_Level are : Graduate
# number of missing values Education_Level are: 0

# %% [markdown]
# Eduation level has ordinal datatype (categorical) as it is heirarchy in it.

# %% [markdown]
# ## Visual representation of Education Level attribute

# %%
fig,ax = plt.subplots(figsize= (10,7))
ax = sns.countplot(Bank["Education_Level"])
ax.set_xticklabels(ax.get_xticklabels(),rotation = 40, ha= "right")

count = len(Bank["Education_Level"])
for bar in ax.patches:                                                 # ax.patches returns the rectange object from matplotlib 
    percentage = f"{round(bar.get_height()/count, 2)*100} %"           # first it calculate the bar heightand then dividing by the number of row(to calculate percentage)
                                                                            # in data and multiply with 100 to get the percentage and rounding of by 2 numbers.  
    x = bar.get_x() + bar.get_width() /2                                # get_x: returns the left corrdinate of the rectange, get_width: returns width of rectagle
    y = bar.get_height()                                                # get_height: returns height of rectangle bar.
    ax.annotate(percentage, (x, y), ha = "center", va = "top")          # va: Vertical axis: -> top means percentage would bneath the bar head
                                                                        # annotate: used to annotate over objects. here objects are the bars 
plt.show()
# Out:
# C:\ProgramData\Anaconda3\anaconda3\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## ***Interpretation: Most people are graduates or have completed high school, which adds up to 51% of the total population.

# %% [markdown]
#  ## 5.Analysis of marital status : marital status of card holder

# %%
info_of_cat("Marital_Status")
# Out:
# The Unique values in Marital_Status are: ['Married' 'Single' 'Unknown' 'Divorced']
# The mode in Marital_Status are : Married
# number of missing values Marital_Status are: 0

# %% [markdown]
# Marital status is nominal datatype.

# %% [markdown]
# ## Visual representation of Marital status

# %%
fig,ax= plt.subplots(1,2,figsize= (10,7))                            # value count is a function to calulate the number of the column marital status 
value_marriage = Bank["Marital_Status"].value_counts()               #keeping its classes as index.   
percentage = (value_marriage / len(Bank) )* 100
print(percentage)                                                   # value_counts returns the count of the classes present in the marital status and its index which is the class name 
                                                                    # is accessed by the index; in sequence format and then converted into the list.
sns.countplot( x = Bank["Marital_Status"], ax = ax[0])              # autpct: is the way how the number would print on the graph.
labels = list(value_marriage.index)

ax[1].pie(percentage, labels = labels, autopct = "%1.1f%%",  )

plt.show()
# Out:
# Married     46.282216
# Single      38.935519
# Unknown      7.396070
# Divorced     7.386195
# Name: Marital_Status, dtype: float64

# %% [markdown]
# ## ***Interpretation:  46% of the people are Married and 39% are Single.

# %% [markdown]
# ## Analysis of income category : income status of card holder

# %%
info_of_cat("Income_Category")
# Out:
# The Unique values in Income_Category are: ['$60K - $80K' 'Less than $40K' '$80K - $120K' '$40K - $60K' '$120K +'
#  'Unknown']
# The mode in Income_Category are : Less than $40K
# number of missing values Income_Category are: 0

# %% [markdown]
# Income category is a ordinal datatype.

# %% [markdown]
# ## Visual representation of income category attribute.

# %%
print((Bank["Income_Category"].value_counts()/len(Bank))*100)               #First calculated the number of income category via value counts inbuilt function and then 
                                                                            #calculated the percentage of it.
fig, ax = plt.subplots(figsize = (10, 4))
sns.countplot(x = Bank[ 'Income_Category'], ax = ax)
for bar in ax.patches:                                                  # ax.patches returns the rectange object from matplotlib
    percentage = f"{round((bar.get_height() /Bank.shape[0])*100 , 2)} %"  # first it calculate the bar height and then dividing by the number of rows in data and 
                                                                            #multiply with 100 to get the percentage and rounding of by 2 numbers.  
    x = bar.get_x() + bar.get_width() /2                                # get_x: returns the left corrdinate of the rectange, get_width: returns width of rectagle
    y = bar.get_height()                                                # get_height: returns height of rectange
    ax.annotate(percentage, (x, y), va= "bottom", ha = "center" )       # annotate: used to annotate over objects. here objects are the bars.
plt.show()
# Out:
# Less than $40K    35.163425
# $40K - $60K       17.675521
# $80K - $120K      15.157500
# $60K - $80K       13.844179
# Unknown           10.980547
# $120K +            7.178829
# Name: Income_Category, dtype: float64

# %%
fig,ax = plt.subplots(figsize = (10,7))
percentage = (Bank["Income_Category"].value_counts()/ len(Bank))*100
print(percentage)

sns.countplot(x= Bank["Income_Category"], ax = ax)
for bar in ax.patches:
    percentage1 = f"{round((bar.get_height()/ Bank.shape[0])* 100,2)}%"

    x = bar.get_x() + bar.get_width() / 2
    y = bar.get_height()
    ax.annotate(percentage1, (x,y), va = "bottom", ha= "center")
    
plt.show()
# Out:
# Less than $40K    35.163425
# $40K - $60K       17.675521
# $80K - $120K      15.157500
# $60K - $80K       13.844179
# Unknown           10.980547
# $120K +            7.178829
# Name: Income_Category, dtype: float64

# %% [markdown]
# ## ***Interpretation: Majority of the population is earning less than $40k.

# %% [markdown]
# ## Analysis of card category :

# %%
info_of_cat("Card_Category")
# Out:
# The Unique values in Card_Category are: ['Blue' 'Gold' 'Silver' nan 'Platinum']
# The mode in Card_Category are : Blue
# number of missing values Card_Category are: 132

# %% [markdown]
# Card category is a nominal datatype.

# %% [markdown]
# ## Missing Value Treatment : Mode of the card type

# %%
card_mode = Bank.Card_Category.mode()[0]
print(card_mode)
Bank["Card_Category"].fillna(card_mode, inplace = True)
# Out:
# Blue

# %% [markdown]
# ## Visual representation of card category attribute

# %%
data = Bank["Card_Category"].value_counts()                                   #value count is counting the number of values in the column
print(data)
pie, ax = plt.subplots(1, 2, figsize = [20,6])
labels =data.keys()                                                         # Keys returning you the index names in the data
ax[0].pie(x = data, explode = [0.2, 0.2, 0.45, 0.67], labels = labels)         # pctdistance is the distance between the percentage on pie chart from center.
                                                                                #  explode is to split the slices by the distance provided
sns.countplot(x = Bank["Card_Category"], ax = ax[1], order = Bank["Card_Category"].value_counts().index)                                                                                               
plt.title("Card_Category")                                                  # title is used to prints the title on the image. 
plt.show()
# Out:
# Blue        9447
# Silver       544
# Gold         116
# Platinum      20
# Name: Card_Category, dtype: int64

# %% [markdown]
# ## Interpretation : The majority of people using blue card followed by silver. The platinum card sold the least.

# %% [markdown]
# ## user defined function which returns percentage using bar graphs

# %%
def bar_percentage(ax, count: "number of rows in data "):
    for bar in ax.patches:                                            # ax.patches returns the rectange object from matplotlib
        percentage = f"{round((bar.get_height() / count) *100, 2)}%"  # first it calculate the bar height and then dividing by the number of row(to calculate percentage)
                                                                            # in data and multiply with 100 to get the percentage and rounding of by 2 numbers.
        x = bar.get_x() + bar.get_width() /2                          # get_x: returns the left corrdinate of the rectange, get_width: returns width of rectagle
        y = bar.get_height()                                          # get_height: returns height of rectangle bar.
        ax.annotate(percentage, (x, y), va = "bottom", ha = "center") # va: Vertical axis: -> top means percentage would bneath the bar head. top, bottom or center 
                                                                      # ha: Horizontal axis:-> how you want to keep it. can be changed to center, left, right.
                                                                      # annotate: used to annotate over objects. here objects are the bars 
    plt.show()

# %% [markdown]
# ## Analysis of total relationship count : years of relationship with bank

# %%
info_of_cat("Total_Relationship_Count")
# Out:
# The Unique values in Total_Relationship_Count are: [5 6 4 3 2 1]
# The mode in Total_Relationship_Count are : 3
# number of missing values Total_Relationship_Count are: 0

# %% [markdown]
# Total relationship count is ordinal datatype as it is heirarchy in it.

# %% [markdown]
# Visual representation of relationship count attribute

# %%
fig, ax = plt.subplots(figsize  = (10 , 6))
ax = sns.countplot(x = Bank["Total_Relationship_Count"])
bar_percentage(ax, len(Bank))

# %% [markdown]
# ## ***Interpretation: Usually people have three years of relationship with the bank. Then, there is a decline of 3%. Later, there is  very little variation. Approximately 20% of the people tend to leave in their first two years.

# %% [markdown]
# ## 10. Analysis of  Months of Inactivity: Months elapsed since the last activity using a credit card.

# %%
info_of_cat('Months_Inactive_12_mon' )
# Out:
# The Unique values in Months_Inactive_12_mon are: [1 4 2 3 6 0 5]
# The mode in Months_Inactive_12_mon are : 3
# number of missing values Months_Inactive_12_mon are: 0

# %% [markdown]
# ###### Total_Relationship_Count is an ordinal datatype (Categorical) as it is having hierarchy in it.

# %% [markdown]
# Visual representattion of months of activity

# %%
fig, ax = plt.subplots(figsize  = (10 , 6))
ax = sns.countplot(x = Bank['Months_Inactive_12_mon'])
bar_percentage(ax, len(Bank))                         # calling the function to plot the percentage on the bars
plt.show()

# %% [markdown]
# ## ***Interpretation: Majority of the customers are inactive for 3 months.

# %% [markdown]
# # $$\;\;\;\;\;\;Univariate \ Analysis \ of \ Numerical \ Variables$$

# %% [markdown]
# LEVEL 1 Analysis of Numerical Columns
# ----------------------------------------------------------
# Check if the data is discrete or continuous. \
# Measure the central tendency (mean, median, mode) \
# Measure the dispersion values \
# Check for missing values \
# Checking for skewness\
# Check for outliers \
# Think about how the missing values could be treated. \
# Think about the kind of graph/chart that can be plotted using this data.

# %% [markdown]
# User defined function for calculating mean, median, mode, standard deviation, and count of all null values

# %%
def info_of_numerical(col):
    print(f"The mean of the {col} is {Bank[col].mean()}")
    print(f"The median of the {col} is {Bank[col].median()}")
    print(f"The mode of the {col} is {Bank[col].mode()[0]}")
    print(f"The standard deviation of the {col} is {Bank[col].std()}")
    print(f"Number of missing values in the {col} is {Bank[col].isnull().sum()}")

# %%
info_of_numerical("Customer_Age")
# Out:
# The mean of the Customer_Age is 47.285276982324476
# The median of the Customer_Age is 46.0
# The mode of the Customer_Age is 44
# The standard deviation of the Customer_Age is 13.270923260536502
# Number of missing values in the Customer_Age is 0

# %% [markdown]
# Customer Age is Numerical Data.

# %%
## Distributionof customer age

fig,ax = plt.subplots(1,2, figsize = (20,7))
sns.histplot(x = Bank["Customer_Age"], ax =ax[0], color = "m") 
sns.boxplot(x = Bank["Customer_Age"], ax = ax[1], color = "g") 
plt.show()

# %% [markdown]
# In this case, the customer age follows the normal distribution. There are few customers with ages over 77. We can replace the ages greater than 75 with the mean age of other customers.

# %% [markdown]
# Outlliers Analysis and Treatment

# %%
mean = int(Bank.Customer_Age.mean())
# accessing the data higher than 6
x = Bank[Bank["Customer_Age"] > 75].index
for index in x:
    Bank.loc[index, "Customer_Age"] = mean

# %%
x
# Out:
# Int64Index([  60,   72,  160,  198,  366,  389,  431,  544,  602,  702,  893,
#              923, 1220, 1249, 1364, 1463, 1583, 1642, 1687, 1759, 1788, 2169,
#             2272, 2293, 2312, 2347, 2395, 2529, 2690, 2731, 3089, 3317, 3667,
#             3770, 3943, 4062, 4067, 4346, 4460, 4471, 4472, 4518, 4519, 4540,
#             4549, 4579, 5118, 5151, 5340, 5676, 5848, 5881, 5897, 5927, 5957,
#             6205, 6693, 6757, 6773, 6990, 7009, 7032, 7074, 7076, 7100, 7163,
#             7262, 7297, 7385, 7542, 7644, 7764, 7771, 7806, 7915, 7931, 8222,
#             8451, 8543, 8619, 8667, 8802, 9054, 9295, 9407, 9469, 9473, 9475,
#             9527, 9534, 9619, 9736, 9778, 9809, 9871, 9888],
#            dtype='int64')

# %%
info_of_numerical("Customer_Age")
# Out:
# The mean of the Customer_Age is 46.32931766564629
# The median of the Customer_Age is 46.0
# The mode of the Customer_Age is 47
# The standard deviation of the Customer_Age is 7.977505937702698
# Number of missing values in the Customer_Age is 0

# %%
# Distribution of Customer_Age (Outlier Analysis)
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               
sns.histplot(x = Bank["Customer_Age"], ax =ax[0], color = "m") 
sns.boxplot(x = Bank["Customer_Age"], ax = ax[1], color = "g") 
plt.show()

# %% [markdown]
# ***Interpretation: Most likely, customer age follows the normal distribution. Most of the bank customers are in between 40 and 50 years of age.

# %% [markdown]
# # Analysis of Total_Revolving_Bal: Balance that is carried over month to month

# %%
info_of_numerical("Total_Revolving_Bal")
# Out:
# The mean of the Total_Revolving_Bal is 1162.8140614199665
# The median of the Total_Revolving_Bal is 1276.0
# The mode of the Total_Revolving_Bal is 0
# The standard deviation of the Total_Revolving_Bal is 814.9873352357697
# Number of missing values in the Total_Revolving_Bal is 0

# %% [markdown]
# Total_Revolving_Bal is a continuous datatype (Numerical).

# %%
fig, ax = plt.subplots(1, 2, figsize= (15, 7))
sns.histplot(x = Bank['Total_Revolving_Bal'], ax = ax[1], color = "m")                                                                                            
sns.boxplot(x = Bank['Total_Revolving_Bal'], ax = ax[0], color = "g") 
plt.show()

# %% [markdown]
# ***Interpretation: There is a spike at the 0 Revolving Balance, which indicates the majority of people tend to have 0 Revolving Balance. Around 25% of the customers do not have a revolving balance, i.e. they settle the credit card bill within a month. Around 75% of customers do not pay the credit card balance on time. These are the profitable customers to the bank (they pay interest on the revolving balance).

# %% [markdown]
# ## Analysis of Avg_Open_To_Buy:

# %% [markdown]
# Difference between the credit limit assigned to a cardholder and the present balance on the account at that time.

# %% [markdown]
# Monthly credit limit is 12000.If the customer spends 5000 in a month, the remaining balance is 7000, which is called as Average open to buy.

# %%
info_of_numerical("Avg_Open_To_Buy")
# Out:
# The mean of the Avg_Open_To_Buy is 7469.139636614887
# The median of the Avg_Open_To_Buy is 3474.0
# The mode of the Avg_Open_To_Buy is 1438.3
# The standard deviation of the Avg_Open_To_Buy is 9090.685323679128
# Number of missing values in the Avg_Open_To_Buy is 0

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))
sns.histplot(Bank["Avg_Open_To_Buy"], ax = ax[1], color= "g")     
sns.boxplot(x = Bank['Avg_Open_To_Buy'], ax = ax[0], color = "y") 
plt.show()

# %% [markdown]
# Outliers Analysis :
# This is right skewed data but the strength of outliers is increasing at the end of the tail which indicates that outliers are not a human error but some people are showing behavior other than population.

# %% [markdown]
# ## Analysis of the Total Transaction Count: Number of transactions made by the card holder

# %%
info_of_numerical("Total_Trans_Ct")
# Out:
# The mean of the Total_Trans_Ct is 64.85869457884863
# The median of the Total_Trans_Ct is 67.0
# The mode of the Total_Trans_Ct is 81
# The standard deviation of the Total_Trans_Ct is 23.472570449233046
# Number of missing values in the Total_Trans_Ct is 0

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))
sns.histplot(x = Bank['Total_Trans_Ct'], ax = ax[0]) 
sns.boxplot(x = Bank["Total_Trans_Ct"], ax = ax[1])
plt.show()

# %% [markdown]
# ***Interpretation: Majority of the customers are making more than 50 transactions.

# %% [markdown]
# ## Analysis of the Avg_Utilization_Ratio: It is a ratio of Total Revolving Balance to Credit Limit

# %% [markdown]
# Average Utilisation Ration : Total Revolving balance / Credit Limit

# %%
info_of_numerical("Avg_Utilization_Ratio")
# Out:
# The mean of the Avg_Utilization_Ratio is 0.2748935518909845
# The median of the Avg_Utilization_Ratio is 0.176
# The mode of the Avg_Utilization_Ratio is 0.0
# The standard deviation of the Avg_Utilization_Ratio is 0.2756914692523933
# Number of missing values in the Avg_Utilization_Ratio is 0

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))
sns.histplot(Bank["Avg_Utilization_Ratio"], ax = ax[1], color= "g")     
sns.boxplot(x = Bank['Avg_Utilization_Ratio'], ax = ax[0], color = "y") 
plt.show()

# %% [markdown]
# This is a right skewed data with no outliers.

# %% [markdown]
# ***Interpretation: Around 75% of the customers are having low utilization (less than 0.5 utilization).

# %% [markdown]
# # Level 2 Analysis (Getting closer to the BIG QUESTION: Churn Analysis)

# %%
print(tabulate({"Categorical":categorical,
                "continuous": continuous}, headers = ["categorical", "continuous"]))
# Out:
# categorical               continuous
# ------------------------  ---------------------
# Attrition_Flag            CLIENTNUM
# Gender                    Customer_Age
# Education_Level           Dependent_count
# Marital_Status            Credit_Limit
# Income_Category           Total_Revolving_Bal
# Card_Category             Avg_Open_To_Buy
# Months_on_book            Total_Trans_Amt
# Total_Relationship_Count  Total_Trans_Ct
# Months_Inactive_12_mon    Avg_Utilization_Ratio
# Contacts_Count_12_mon

# %% [markdown]
# ## 1) Level 2 : Categorical to Categorical column

# %% [markdown]
# ## Relationship of Attrition_Flag with Gender

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "Gender", hue = "Attrition_Flag", data = Bank)
plt.show()

# %% [markdown]
# **Interpretation: Percentage of women getting churned out is more than men.

# %% [markdown]
# ## Relationship of Attrition Flag with Education_Level

# %%
pd.crosstab(Bank["Attrition_Flag"], Bank["Education_Level"])
# Out:
# Education_Level    College  Doctorate  Graduate  High School  Post-Graduate  \
# Attrition_Flag
# Attrited Customer      154         95       487          306             92
# Existing Customer      859        356      2641         1707            424
#
# Education_Level    Uneducated  Unknown
# Attrition_Flag
# Attrited Customer         237      256
# Existing Customer        1250     1263

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "Education_Level", hue = "Attrition_Flag", data = Bank)
plt.show()

# %% [markdown]
# ***Interpretation: Graduate and High School customers have a higher Attrition rate compared to another education level.

# %% [markdown]
# ## Relationship of Attrition Flag with Income Category

# %%
pd.crosstab(Bank["Attrition_Flag"], Bank["Income_Category"])
# Out:
# Income_Category    $120K +  $40K - $60K  $60K - $80K  $80K - $120K  \
# Attrition_Flag
# Attrited Customer      126          271          189           242
# Existing Customer      601         1519         1213          1293
#
# Income_Category    Less than $40K  Unknown
# Attrition_Flag
# Attrited Customer             612      187
# Existing Customer            2949      925

# %%
fig,ax = plt.subplots(figsize = (10,7))
sns.countplot(x = "Income_Category", hue = "Attrition_Flag", data= Bank)
plt.show()

# %% [markdown]
# ***Interpretation: Almost 20-30% of customers who attrited are earning less than $40,000.

# %% [markdown]
# ## Relationship of Attrition_Flag with Card_Category

# %%
pd.crosstab(Bank["Attrition_Flag"], Bank["Card_Category"])
# Out:
# Card_Category      Blue  Gold  Platinum  Silver
# Attrition_Flag
# Attrited Customer  1521    21         5      80
# Existing Customer  7926    95        15     464

# %%
fig,ax = plt.subplots(figsize = (10,7))
sns.countplot(x = "Card_Category", hue = "Attrition_Flag", data = Bank)
plt.show()

# %% [markdown]
# Interpretation = Majority of the Attrited customers are from Blue Card Holders And also be noted that majority of the customers are from Blue Card Category.

# %% [markdown]
# ## 2) Categorical to Numerical Column

# %%
continuous
# Out:
# ['CLIENTNUM',
#  'Customer_Age',
#  'Dependent_count',
#  'Credit_Limit',
#  'Total_Revolving_Bal',
#  'Avg_Open_To_Buy',
#  'Total_Trans_Amt',
#  'Total_Trans_Ct',
#  'Avg_Utilization_Ratio']

# %% [markdown]
# ## Relationship of Attrition Flag with Customer Age

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = Bank["Customer_Age"], hue = Bank["Attrition_Flag"], ax = ax[0])
sns.boxplot(y = Bank["Customer_Age"], x = Bank["Attrition_Flag"], ax = ax[1])
plt.show()

# %% [markdown]
# Interpretation = Most of the Bank Customers are from 40-50 years of age.

# %% [markdown]
# ## Relationship of Attrited Flag with Credit Limit

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = Bank["Credit_Limit"], hue = Bank["Attrition_Flag"], ax = ax[0])
sns.boxplot(x = Bank["Attrition_Flag"] ,y = Bank["Credit_Limit"] , ax = ax[1])
plt.show()

# %% [markdown]
# Interpretation = This is right skewed data. There is not the significant Difference between the Credit Limit of the Existing customer and Attrited Customer.

# %% [markdown]
# ## Relationship between the Attrition_Flag with Dependent_count

# %%
pd.crosstab(Bank["Attrition_Flag"], Bank["Dependent_count"])
# Out:
# Dependent_count      0     1     2     3     4    5
# Attrition_Flag
# Attrited Customer  134   268   422   480   258   65
# Existing Customer  764  1557  2277  2238  1304  360

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = Bank["Dependent_count"], hue = Bank["Attrition_Flag"], ax = ax[0])
sns.boxplot(x = Bank["Attrition_Flag"] ,y = Bank["Dependent_count"] , ax = ax[1])
plt.show()

# %% [markdown]
# Interpretation = There are Majority of the customers are from 2 and 3 dependent counts on their card and also most of the customers are from the 2-3 dependent counts.

# %% [markdown]
#  ## Relationship of Attrition_Flag with Avg_Utilization_Ratio

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = Bank["Avg_Utilization_Ratio"], hue = Bank["Attrition_Flag"], ax = ax[0])
sns.boxplot(x = Bank["Attrition_Flag"] ,y = Bank["Avg_Utilization_Ratio"] , ax = ax[1])
plt.show()

# %% [markdown]
# Interpretation: Customers who churned have very low usage. Most of them haven't used their cards. Around 75% of customers who churned have usage only of only 0.2%.

# %% [markdown]
# ## Level 3 Further Analysis Questions

# %%
print(tabulate({"Categorical":categorical,
                "continuous": continuous}, headers = ["categorical", "continuous"]))
# Out:
# categorical               continuous
# ------------------------  ---------------------
# Attrition_Flag            CLIENTNUM
# Gender                    Customer_Age
# Education_Level           Dependent_count
# Marital_Status            Credit_Limit
# Income_Category           Total_Revolving_Bal
# Card_Category             Avg_Open_To_Buy
# Months_on_book            Total_Trans_Amt
# Total_Relationship_Count  Total_Trans_Ct
# Months_Inactive_12_mon    Avg_Utilization_Ratio
# Contacts_Count_12_mon

# %% [markdown]
# ## We know that the female gender has the most churned Customers, So we check the details about Female Gender.

# %% [markdown]
# ## 1) Which Age group of womern has larger Churn ?

# %%
Females =Bank[(Bank["Gender"]=="F") & (Bank["Attrition_Flag"]=="Attrited Customer")]
bins = [0,30,40,50,60,70]
labels = ["Young", 'Adult', "Senior", "Super-Senior", "Old"]
Bankf1 = pd.cut(Females['Customer_Age'], bins = bins, labels = labels )
Bankf1 = Bankf1.value_counts()
Bankf1
# Out:
# Senior          460
# Super-Senior    262
# Adult           171
# Old              29
# Young            17
# Name: Customer_Age, dtype: int64

# %%
fig,ax= plt.subplots(figsize = (10,7))
plt.pie(x = Bankf1,explode = [0.02, 0.04, 0.03, 0,0] ,labels =Bankf1.index, autopct = '%1.1f%%', pctdistance = 0.5) #autopct is used to present the percentage, explode is used to seprate the pie
                                                                                            # pctdistance is the distance betweeen the percentage numbers on the pie
plt.title("Female Age group Attrition")
plt.show()

# %% [markdown]
# Interpretation: Senior women have higher churn about (49%),followed by Super-Senior(28%).

# %% [markdown]
# ## 2) Analyze the churn of women customers based on their education levels.

# %%
Females= Bank[(Bank["Gender"]=="F") & (Bank["Attrition_Flag"]=="Attrited Customer")]

Bankf2= Females["Education_Level"] 
Bankf2 = Bankf2.value_counts()
Bankf2
# Out:
# Graduate         296
# High School      175
# Unknown          152
# Uneducated       128
# College           79
# Doctorate         64
# Post-Graduate     45
# Name: Education_Level, dtype: int64

# %%
pie, ax = plt.subplots(figsize = [10,6])
plt.pie(x = Bankf2,labels =Bankf2.index, autopct = "%1.1f%%", pctdistance = 0.5) #autopct is used to present the percentage, explode is used to seprate the pie
                                                                                            # pctdistance is the distance betweeen the percentage numbers on the pie
plt.title("Female Age group Attrition ")
plt.show()

# %% [markdown]
# Interpretation = Based on Education Level. The Graduate Females are more churned out(32%) followed by High-School Candidates(19%) compared to those who are post-graduate, Doctorate, College and Uneducated women.

# %% [markdown]
# ## 3) Do you think the average total transaction amount of women who churned out is different from those who are still with the bank?

# %%
with_bank = Bank[(Bank["Gender"] == "F") & (Bank["Attrition_Flag"] == "Existing Customer")]
with_bank_mean = with_bank["Total_Trans_Amt"].mean()

# %%
print("The Mean of the Existing Customers are",with_bank_mean )
# Out:
# The Mean of the Existing Customers are 4650.578912021491

# %%
left_bank = Bank[(Bank["Gender"] == "F") & (Bank["Attrition_Flag"] == "Attrited Customer")]
left_bank_mean = left_bank["Total_Trans_Amt"].mean()

# %%
print("The Mean of the Attrited Customers are", left_bank_mean)
# Out:
# The Mean of the Attrited Customers are 2792.5995740149096

# %%
avg_Total_Trans_Amt= [4650, 2792]
fig, ax = plt.subplots(figsize = [10,6])
plt.pie(avg_Total_Trans_Amt, labels = ["Existing Customers", "Attrited Customers"], autopct= '%1.1f%%')
plt.title("Difference of Transaction in women")
plt.show()

# %% [markdown]
# Interpretation: Yes, there is a difference in the transaction amount made by the Existing women customers and  Attrited women customers.

# %% [markdown]
# ## 4. Age-wise analysis of the customers whose dependent count is 2 or 3 (Existing and Churned out)

# %%
Age_dependent = Bank[(Bank["Dependent_count"] == 2) | (Bank["Dependent_count"] == 3)]
g = sns.FacetGrid(Age_dependent, col = "Dependent_count", height = 7)
g.map(sns.histplot, "Customer_Age")
plt.show()

# %%
# checking for the average of the dependent count 2 and 3

dep_2_mean = Age_dependent[Age_dependent["Dependent_count"] == 2]["Customer_Age"].mean()
print(dep_2_mean)

dep_3_mean = Age_dependent[Age_dependent["Dependent_count"] == 3]["Customer_Age"].mean()
print(dep_3_mean)
# Out:
# 46.32826972952945
# 45.50257542310523

# %% [markdown]
# Interpretation: Most of the customers have the same age distribution based on their dependent counts.

# %% [markdown]
# ## 5. Is there any relation between the number of dependents (2 or 3) and the education level of customers who are existing and those who churned out?

# %%
Education_dependent = Bank[(Bank["Dependent_count"] == 2) | (Bank["Dependent_count"] == 3)]

# %%
import warnings
warnings.filterwarnings('ignore')

g = sns.FacetGrid(Education_dependent, col ="Dependent_count", height = 7)
g.map(sns.countplot, "Education_Level")
plt.show()

# %% [markdown]
# Interpretation = The Customers who have 2 dependent counts are from High School and College Pass Outs.The Customers who have 3 dependent counts are from Graduate and High School Pass out.

# %% [markdown]
# ### We know that Based on Education Level, Graduate and High School Pass outs female customers are more churned customers compared to other Education Levels.so We will Check all the details abouts Graduate and High School female churned out customers.

# %% [markdown]
# ## Card Category Wise Analysis of customers who are high school passouts and churned out.

# %%
Bank_data = Bank[(Bank["Education_Level"] == "High School") | (Bank["Attrition_Flag"] == "Attrited Customer")]
print("There are "+str(len(Bank_data))+" number of customers who are high school pass outs and churned out.")
# Out:
# There are 3334 number of customers who are high school pass outs and churned out.

# %%
info_of_cat("Card_Category")
# Out:
# The Unique values in Card_Category are: ['Blue' 'Gold' 'Silver' 'Platinum']
# The mode in Card_Category are : Blue
# number of missing values Card_Category are: 0

# %%
Card_data = Bank_data["Card_Category"].value_counts()                                   #value count is counting the number of values in the column
print(Card_data)

fig, ax = plt.subplots(1, 2, figsize = [20,6])
labels =Card_data.keys()                                                         # Keys returning you the index names in the data
ax[0].pie(x = Card_data, explode = [0.2, 0.2, 0.45, 0.67], labels = labels, autopct = "%1.1f%%")         # pctdistance is the distance between the percentage on pie chart from center.
                                                                                #  explode is to split the slices by the distance provided
sns.countplot(x = Bank_data["Card_Category"], ax = ax[1], order = Bank_data["Card_Category"].value_counts().index)                                                                                               
plt.title("Card_Category(High School)")                                                  # title is used to prints the title on the image. 
plt.show()
# Out:
# Blue        3123
# Silver       162
# Gold          43
# Platinum       6
# Name: Card_Category, dtype: int64

# %% [markdown]
# Interpretation : Majority of the High School Pass out women are using Blue card(94%) followed by Silver Card.

# %%
Bank_data1 = Bank[(Bank["Education_Level"] == "Graduate") | (Bank["Attrition_Flag"] == "Attrited Customer")]
print("There are "+str(len(Bank_data1))+" number of customers who are Graduate pass outs and churned out.")
# Out:
# There are 4268 number of customers who are Graduate pass outs and churned out.

# %%
Card_data1 = Bank_data1["Card_Category"].value_counts()
print(Card_data1)

fig,ax = plt.subplots(1,2, figsize = (20,6))
labels = Card_data1.keys()
ax[0].pie(x = Card_data1, explode = [0.2, 0.2, 0.47, 0.65], autopct = "%1.1f%%", labels = labels)
sns.countplot(x = Bank_data1["Card_Category"], ax= ax[1], order =Bank_data1["Card_Category"].value_counts().index)
plt.title(" Card Category(Graduate)")
plt.show()
# Out:
# Blue        3972
# Silver       235
# Gold          51
# Platinum      10
# Name: Card_Category, dtype: int64

# %% [markdown]
# Interpretation : Majority of the Graduate card Holders are from the Blue Card Holders followed by Silver. Platinum Card Holders are least.

# %% [markdown]
# ## Income Category wise breakdown of the customers who are high school pass outs and are still with the bank.

# %%
Bank_income = Bank[(Bank["Education_Level"] == "High School") | (Bank["Attrition_Flag"] == "Existing Customer")]
print("There are "+str(len(Bank_income))+" number of customers who are high school pass outs and still with the bank.")
# Out:
# There are 8806 number of customers who are high school pass outs and still with the bank.

# %%
info_of_cat("Income_Category")
# Out:
# The Unique values in Income_Category are: ['$60K - $80K' 'Less than $40K' '$80K - $120K' '$40K - $60K' '$120K +'
#  'Unknown']
# The mode in Income_Category are : Less than $40K
# number of missing values Income_Category are: 0

# %%
Income_data = Bank_income["Income_Category"].value_counts()
print(Income_data)

fig,ax = plt.subplots(1,2, figsize = (20,6))
labels = Income_data.keys()
ax[0].pie(x = Income_data, explode = [0.01,0.01,0.01,0.02,0.03,0.042], autopct = "%1.1f%%", labels = labels)
sns.countplot(x = Bank_income["Income_Category"], ax= ax[1], order = Bank_income["Income_Category"].value_counts().index)
plt.title(" Income Category(High School)")
plt.show()
# Out:
# Less than $40K    3050
# $40K - $60K       1570
# $80K - $120K      1334
# $60K - $80K       1255
# Unknown            968
# $120K +            629
# Name: Income_Category, dtype: int64

# %% [markdown]
# Interpretation : Majority High School Pass out female customers who are still with the Bank are from less than 40k Income category.

# %% [markdown]
# ## Income Category wise breakdown of the customers who are Graduate pass outs and are still with the bank.

# %%
Bank_income1 = Bank[(Bank["Education_Level"] == "Graduate") | (Bank["Attrition_Flag"] == "Existing Customer")]
print("There are "+str(len(Bank_income1))+" number of customers who are Graduate pass outs and still with the bank.")
# Out:
# There are 8987 number of customers who are Graduate pass outs and still with the bank.

# %%
Income_data1 = Bank_income1["Income_Category"].value_counts()
print(Income_data1)

fig,ax = plt.subplots(1,2, figsize = (20,6))
labels = Income_data1.keys()
ax[0].pie(x = Income_data1, explode = [0.01,0.01,0.01,0.02,0.03,0.042], autopct = "%1.1f%%", labels = labels)
sns.countplot(x = Bank_income1["Income_Category"], ax= ax[1], order = Bank_income1["Income_Category"].value_counts().index)
plt.title(" Income Category(High School)")
plt.show()
# Out:
# Less than $40K    3159
# $40K - $60K       1596
# $80K - $120K      1360
# $60K - $80K       1265
# Unknown            974
# $120K +            633
# Name: Income_Category, dtype: int64

# %% [markdown]
# Interpretation : Majority Graduate female customers who are still with the Bank are from less than 40k Income category.
